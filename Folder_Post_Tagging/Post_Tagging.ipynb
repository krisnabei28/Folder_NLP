# %%
import nltk
from nltk.tag import CRFTagger

cr = CRFTagger()
cr.set_model_file("all_indo_man_tag_corpus_model.crf.tagger")

# %%
loadData = open("/home/krisnabei/Documents/Dokumen_Krisna/NLP/Post_Tagging_Code/dataSet.txt", "r")
inputData = loadData.read()
print(inputData)
# Out:
# Luhut menjelaskan, operasi intelijen yang dimaksud bukan dalam rangka mengirimkan pasukan khusus ke wilayah Filipina.
# Menurut Luhut, selama upaya pembebasan, Pemerintah Indonesia selalu berkoordinasi dengan Pemerintah Filipina dengan bertukar informasi, nasihat strategi, dan asistensi.
# Jaksa Agung Prasetyo dan Menhub Jonan menandatangani ini dihadapan beberapa staf kedua pihak.
# Saya urut dari paling bawah masalah pengamanan aset, kalau dikumpulkan aset-aset negara atas nama Kemenhub masih banyak yang tercecer di kiri kanannya.
# Jadi ini mohon bantuan bapak kerja samanya unutuk ditata ulang untuk kepentingan bangsa dan negara," kata Jonan di Kejagung, Jl Sultan Hasanuddin, Jakarta Selatan, Kamis (24/3/2016).
# Misal kalau Kemenhub ingin ingin memperbaiki bandara, Jonan bilang ada saja pihak yang menuntut.
# ...

# %%
postTagging = cr.tag_sents([inputData.split()])
postTagging = postTagging[0]
print(postTagging)
# Out:
# [('Luhut', 'NN'), ('menjelaskan,', 'NN'), ('operasi', 'NN'), ('intelijen', 'NN'), ('yang', 'SC'), ('dimaksud', 'VB'), ('bukan', 'NEG'), ('dalam', 'IN'), ('rangka', 'NN'), ('mengirimkan', 'VB'), ('pasukan', 'NN'), ('khusus', 'JJ'), ('ke', 'IN'), ('wilayah', 'NN'), ('Filipina.', 'NNP'), ('Menurut', 'NNP'), ('Luhut,', 'NNP'), ('selama', 'IN'), ('upaya', 'NN'), ('pembebasan,', 'NNP'), ('Pemerintah', 'NNP'), ('Indonesia', 'NNP'), ('selalu', 'RB'), ('berkoordinasi', 'VB'), ('dengan', 'IN'), ('Pemerintah', 'NNP'), ('Filipina', 'NNP'), ('dengan', 'IN'), ('bertukar', 'NN'), ('informasi,', 'NN'), ('nasihat', 'VB'), ('strategi,', 'NN'), ('dan', 'CC'), ('asistensi.', 'NNP'), ('Jaksa', 'NNP'), ('Agung', 'NNP'), ('Prasetyo', 'NNP'), ('dan', 'CC'), ('Menhub', 'NNP'), ('Jonan', 'NNP'), ('menandatangani', 'VB'), ('ini', 'PR'), ('dihadapan', 'NN'), ('beberapa', 'CD'), ('staf', 'NN'), ('kedua', 'OD'), ('pihak.', 'NND'), ('Saya', 'PRP'), ('urut', 'VB'), ('dari', 'IN'), ('paling', 'RB'), ('bawah', 'VB'),
# ...
